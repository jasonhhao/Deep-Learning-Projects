# %%
from __future__ import division, print_function, absolute_import
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

mnist = input_data.read_data_sets("../MNIST_data/", one_hot=True)
# Out:
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.
# WARNING:tensorflow:From <ipython-input-1-50b65c3cbbf3>:5: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting ../MNIST_data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting ../MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting ../MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting ../MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
learning_rate = 0.001
num_steps = 1000
batch_size = 128
display_step = 10

num_input = 784 # (img shape: 28*28)
num_classes = 10 # (0-9 digits)
dropout = 0.75 

X = tf.placeholder(tf.float32, [None, num_input])
Y = tf.placeholder(tf.float32, [None, num_classes])
keep_prob = tf.placeholder(tf.float32) # dropout (keep probability)，保留i

# %%
def conv2d(x, W, b, strides=1):
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)


def maxpool2d(x, k=2):
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1], padding='SAME')


def conv_net(x, weights, biases, dropout):

    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    conv1 = maxpool2d(conv1, k=2)

    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    conv2 = maxpool2d(conv2, k=2)

    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)

    fc1 = tf.nn.dropout(fc1, dropout)

    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# %%
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, num_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([num_classes]))
}

logits = conv_net(X, weights, biases, keep_prob)
prediction = tf.nn.softmax(logits)

loss_op = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(
    logits=logits, labels=Y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
train_op = optimizer.minimize(loss_op)

correct_pred = tf.equal(tf.argmax(prediction, 1), tf.argmax(Y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

init = tf.global_variables_initializer()
# Out:
# WARNING:tensorflow:From <ipython-input-4-736324252919>:23: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.

# %%
with tf.Session() as sess:

    sess.run(init)

    for step in range(1, num_steps+1):
        
        batch_x, batch_y = mnist.train.next_batch(batch_size)

        sess.run(train_op, feed_dict={X: batch_x, Y: batch_y, keep_prob: dropout})
        
        if step % display_step == 0 or step == 1:

            loss, acc = sess.run([loss_op, accuracy], feed_dict={X: batch_x,
                                                                 Y: batch_y,
                                                                 keep_prob: 1.0})
            print("Step " + str(step) + ", Minibatch Loss= " + \
                  "{:.4f}".format(loss) + ", Training Accuracy= " + \
                  "{:.3f}".format(acc))

    # Calculate accuracy for 256 MNIST test images
    print("Testing Accuracy:", \
        sess.run(accuracy, feed_dict={X: mnist.test.images[:256],
                                      Y: mnist.test.labels[:256],
                                      keep_prob: 1.0}))
# Out:
# Step 1, Minibatch Loss= 75590.8906, Training Accuracy= 0.094
# Step 10, Minibatch Loss= 24858.6055, Training Accuracy= 0.266
# Step 20, Minibatch Loss= 8495.7871, Training Accuracy= 0.484
# Step 30, Minibatch Loss= 5036.6025, Training Accuracy= 0.664
# Step 40, Minibatch Loss= 3494.3188, Training Accuracy= 0.766
# Step 50, Minibatch Loss= 3734.6033, Training Accuracy= 0.734
# Step 60, Minibatch Loss= 3312.7307, Training Accuracy= 0.766
# Step 70, Minibatch Loss= 1928.3813, Training Accuracy= 0.859
# Step 80, Minibatch Loss= 1598.5271, Training Accuracy= 0.867
# Step 90, Minibatch Loss= 3013.6670, Training Accuracy= 0.844
# Step 100, Minibatch Loss= 1016.2430, Training Accuracy= 0.906
# Step 110, Minibatch Loss= 1585.4613, Training Accuracy= 0.891
# Step 120, Minibatch Loss= 882.4069, Training Accuracy= 0.930
# Step 130, Minibatch Loss= 1414.5432, Training Accuracy= 0.867
# Step 140, Minibatch Loss= 1168.7332, Training Accuracy= 0.922
# Step 150, Minibatch Loss= 796.0300, Training Accuracy= 0.922
# Step 160, Minibatch Loss= 1171.1676, Training Accuracy= 0.914
# Step 170, Minibatch Loss= 369.3253, Training Accuracy= 0.938
# Step 180, Minibatch Loss= 1260.1118, Training Accuracy= 0.875
# Step 190, Minibatch Loss= 1085.9609, Training Accuracy= 0.938
# Step 200, Minibatch Loss= 1679.2297, Training Accuracy= 0.898
# Step 210, Minibatch Loss= 598.5106, Training Accuracy= 0.898
# Step 220, Minibatch Loss= 1107.6565, Training Accuracy= 0.898
# Step 230, Minibatch Loss= 386.6798, Training Accuracy= 0.961
# Step 240, Minibatch Loss= 678.2784, Training Accuracy= 0.938
# Step 250, Minibatch Loss= 1636.4763, Training Accuracy= 0.914
# Step 260, Minibatch Loss= 1110.4796, Training Accuracy= 0.898
# Step 270, Minibatch Loss= 1116.9998, Training Accuracy= 0.906
# Step 280, Minibatch Loss= 1059.0334, Training Accuracy= 0.938
# Step 290, Minibatch Loss= 563.0998, Training Accuracy= 0.945
# Step 300, Minibatch Loss= 810.7764, Training Accuracy= 0.930
# Step 310, Minibatch Loss= 1265.4037, Training Accuracy= 0.914
# Step 320, Minibatch Loss= 701.2083, Training Accuracy= 0.898
# Step 330, Minibatch Loss= 851.3862, Training Accuracy= 0.922
# Step 340, Minibatch Loss= 643.7158, Training Accuracy= 0.938
# Step 350, Minibatch Loss= 807.6596, Training Accuracy= 0.945
# Step 360, Minibatch Loss= 954.6413, Training Accuracy= 0.922
# Step 370, Minibatch Loss= 1321.2510, Training Accuracy= 0.922
# Step 380, Minibatch Loss= 377.3520, Training Accuracy= 0.945
# Step 390, Minibatch Loss= 1627.9777, Training Accuracy= 0.859
# Step 400, Minibatch Loss= 328.8942, Training Accuracy= 0.961
# Step 410, Minibatch Loss= 1076.7048, Training Accuracy= 0.930
# Step 420, Minibatch Loss= 864.9612, Training Accuracy= 0.930
# Step 430, Minibatch Loss= 716.4969, Training Accuracy= 0.930
# Step 440, Minibatch Loss= 113.4991, Training Accuracy= 0.977
# Step 450, Minibatch Loss= 436.5612, Training Accuracy= 0.953
# Step 460, Minibatch Loss= 326.2876, Training Accuracy= 0.961
# Step 470, Minibatch Loss= 470.8874, Training Accuracy= 0.914
# Step 480, Minibatch Loss= 573.5245, Training Accuracy= 0.945
# Step 490, Minibatch Loss= 672.9632, Training Accuracy= 0.898
# Step 500, Minibatch Loss= 333.6277, Training Accuracy= 0.969
# Step 510, Minibatch Loss= 1241.1462, Training Accuracy= 0.922
# Step 520, Minibatch Loss= 199.6998, Training Accuracy= 0.961
# Step 530, Minibatch Loss= 516.4103, Training Accuracy= 0.938
# Step 540, Minibatch Loss= 340.4807, Training Accuracy= 0.953
# Step 550, Minibatch Loss= 149.2917, Training Accuracy= 0.969
# Step 560, Minibatch Loss= 228.4686, Training Accuracy= 0.977
# Step 570, Minibatch Loss= 354.8172, Training Accuracy= 0.953
# Step 580, Minibatch Loss= 427.3284, Training Accuracy= 0.945
# Step 590, Minibatch Loss= 819.8510, Training Accuracy= 0.930
# Step 600, Minibatch Loss= 454.4935, Training Accuracy= 0.953
# Step 610, Minibatch Loss= 370.2484, Training Accuracy= 0.953
# Step 620, Minibatch Loss= 246.9011, Training Accuracy= 0.969
# Step 630, Minibatch Loss= 169.6389, Training Accuracy= 0.969
# Step 640, Minibatch Loss= 528.5269, Training Accuracy= 0.961
# Step 650, Minibatch Loss= 721.4536, Training Accuracy= 0.945
# Step 660, Minibatch Loss= 256.4257, Training Accuracy= 0.969
